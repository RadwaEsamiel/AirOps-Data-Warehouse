# %%
from datetime import datetime, timedelta
import random
import string

airports = [
    {
        "Airport_Name": "John F. Kennedy International Airport",
        "Country": "United States",
        "City": "New York City",
        "Latitude": 40.6413,
        "Longitude": -73.7781,
        "Region": "North America"
    },
    {
        "Airport_Name": "Los Angeles International Airport",
        "Country": "United States",
        "City": "Los Angeles",
        "Latitude": 33.9416,
        "Longitude": -118.4085,
        "Region": "North America"
    },
    {
        "Airport_Name": "London Heathrow Airport",
        "Country": "United Kingdom",
        "City": "London",
        "Latitude": 51.4694,
        "Longitude": -0.4507,
        "Region": "Europe"
    },
    {
        "Airport_Name": "Dubai International Airport",
        "Country": "United Arab Emirates",
        "City": "Dubai",
        "Latitude": 25.2532,
        "Longitude": 55.3657,
        "Region": "Middle East"
    },
    {
        "Airport_Name": "Tokyo Haneda Airport",
        "Country": "Japan",
        "City": "Tokyo",
        "Latitude": 35.5533,
        "Longitude": 139.781,
        "Region": "Asia"
    },
    {
        "Airport_Name": "Beijing Capital International Airport",
        "Country": "China",
        "City": "Beijing",
        "Latitude": 40.0799,
        "Longitude": 116.587,
        "Region": "Asia"
    },
    {
        "Airport_Name": "Paris Charles de Gaulle Airport",
        "Country": "France",
        "City": "Paris",
        "Latitude": 49.0097,
        "Longitude": 2.5479,
        "Region": "Europe"
    },
    {
        "Airport_Name": "Frankfurt Airport",
        "Country": "Germany",
        "City": "Frankfurt",
        "Latitude": 50.0333,
        "Longitude": 8.5706,
        "Region": "Europe"
    },
    {
        "Airport_Name": "Singapore Changi Airport",
        "Country": "Singapore",
        "City": "Singapore",
        "Latitude": 1.3644,
        "Longitude": 103.9915,
        "Region": "Asia"
    },
    {
        "Airport_Name": "Amsterdam Airport Schiphol",
        "Country": "Netherlands",
        "City": "Amsterdam",
        "Latitude": 52.3091,
        "Longitude": 4.7679,
        "Region": "Europe"
    },
    {
        "Airport_Name": "Hong Kong International Airport",
        "Country": "Hong Kong",
        "City": "Hong Kong",
        "Latitude": 22.308,
        "Longitude": 114.169,
        "Region": "Asia"
    },
    {
        "Airport_Name": "Denver International Airport",
        "Country": "United States",
        "City": "Denver",
        "Latitude": 39.8561,
        "Longitude": -104.6737,
        "Region": "North America"
    },
    {
        "Airport_Name": "Dallas/Fort Worth International Airport",
        "Country": "United States",
        "City": "Dallas/Fort Worth",
        "Latitude": 32.8998,
        "Longitude": -97.038,
        "Region": "North America"
    },
    {
        "Airport_Name": "Sydney Airport",
        "Country": "Australia",
        "City": "Sydney",
        "Latitude": -33.9461,
        "Longitude": 151.1772,
        "Region": "Oceania"
    },
    {
        "Airport_Name": "San Francisco International Airport",
        "Country": "United States",
        "City": "San Francisco",
        "Latitude": 37.7749,
        "Longitude": -122.4194,
        "Region": "North America"
    },
    {
        "Airport_Name": "Incheon International Airport",
        "Country": "South Korea",
        "City": "Incheon",
        "Latitude": 37.4692,
        "Longitude": 126.4513,
        "Region": "Asia"
    },
    {
        "Airport_Name": "Madrid-Barajas Adolfo Suárez Airport",
        "Country": "Spain",
        "City": "Madrid",
        "Latitude": 40.4915,
        "Longitude": -3.567,
        "Region": "Europe"
    },
    {
        "Airport_Name": "Toronto Pearson International Airport",
        "Country": "Canada",
        "City": "Toronto",
        "Latitude": 43.6777,
        "Longitude": -79.6248,
        "Region": "North America"
    },
    {
        "Airport_Name": "Munich Airport",
        "Country": "Germany",
        "City": "Munich",
        "Latitude": 48.3537,
        "Longitude": 11.7735,
        "Region": "Europe"
    },
    {
        "Airport_Name": "Zurich Airport",
        "Country": "Switzerland",
        "City": "Zurich",
        "Latitude": 47.4647,
        "Longitude": 8.562,
        "Region": "Europe"
    },
    {
        "Airport_Name": "Cairo International Airport",
        "Country": "Egypt",
        "City": "Cairo",
        "Latitude": 30.1219,
        "Longitude": 31.4056,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Hurghada International Airport",
        "Country": "Egypt",
        "City": "Hurghada",
        "Latitude": 27.1656,
        "Longitude": 33.7991,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Sharm El Sheikh International Airport",
        "Country": "Egypt",
        "City": "Sharm El Sheikh",
        "Latitude": 27.9774,
        "Longitude": 34.3949,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Luxor International Airport",
        "Country": "Egypt",
        "City": "Luxor",
        "Latitude": 25.6759,
        "Longitude": 32.705,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Marsa Alam International Airport",
        "Country": "Egypt",
        "City": "Marsa Alam",
        "Latitude": 25.5577,
        "Longitude": 34.5835,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Alexandria International Airport",
        "Country": "Egypt",
        "City": "Alexandria",
        "Latitude": 31.2001,
        "Longitude": 29.9481,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Aswan International Airport",
        "Country": "Egypt",
        "City": "Aswan",
        "Latitude": 24.9647,
        "Longitude": 32.8194,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Sohag International Airport",
        "Country": "Egypt",
        "City": "Sohag",
        "Latitude": 26.3351,
        "Longitude": 31.9461,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Mersa Matruh Airport",
        "Country": "Egypt",
        "City": "Mersa Matruh",
        "Latitude": 31.3525,
        "Longitude": 27.2221,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Asyut International Airport",
        "Country": "Egypt",
        "City": "Asyut",
        "Latitude": 27.1895,
        "Longitude": 31.1837,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Taba International Airport",
        "Country": "Egypt",
        "City": "Taba",
        "Latitude": 29.5874,
        "Longitude": 34.7783,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Borg El Arab Airport",
        "Country": "Egypt",
        "City": "Borg El Arab",
        "Latitude": 31.1843,
        "Longitude": 29.9492,
        "Region": "Africa"
    },
    {
        "Airport_Name": "El Arish International Airport",
        "Country": "Egypt",
        "City": "El Arish",
        "Latitude": 31.0731,
        "Longitude": 33.8369,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Assiut Airport",
        "Country": "Egypt",
        "City": "Assiut",
        "Latitude": 27.1809,
        "Longitude": 31.3317,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Marsa Matruh International Airport",
        "Country": "Egypt",
        "City": "Marsa Matruh",
        "Latitude": 31.3256,
        "Longitude": 27.2211,
        "Region": "Africa"
    },
    {
        "Airport_Name": "Abu Simbel Airport",
        "Country": "Egypt",
        "City": "Abu Simbel",
        "Latitude": 22.3754,
        "Longitude": 31.6117,
        "Region": "Africa"
    },
    {
        "Airport_Name": "St. Catherine International Airport",
        "Country": "Egypt",
        "City": "St. Catherine",
        "Latitude": 28.6902,
        "Longitude": 34.0625,
        "Region": "Africa"
    }
]

num_runways = [3, 4, 2, 5]
terminal_count = [2, 3, 4]
num_gates = [15, 20, 25]
atc_capacity = [500, 600, 700]
parking_stands = [20, 25, 30]
guest_capacity = [2000, 2500, 3000]

def generate_airport_id():
    prefix = ''.join(random.choices(string.ascii_uppercase, k=3))
    suffix = ''.join(random.choices(string.digits, k=4))
    return f"{prefix}-{suffix}"

# %%
def generate_insert_statement(num_runways_list, terminal_count_list, num_gates_list, atc_capacity_list, parking_stands_list, guest_capacity_list):
    with open('Populate_Airport.SQL', 'w') as data:
        for i in range(len(airports)):
            airport = airports[i]
            airport_id = generate_airport_id()
            airport_name = airport["Airport_Name"]
            country = airport["Country"]
            city = airport["City"]
            latitude = airport["Latitude"]
            longitude = airport["Longitude"]
            region = airport["Region"]
            num_runways = random.choice(num_runways_list)
            terminal_count = random.choice(terminal_count_list)
            num_gates = random.choice(num_gates_list)
            atc_capacity = random.choice(atc_capacity_list)
            aircraft_parking_stands = random.choice(parking_stands_list)
            guest_capacity = random.choice(guest_capacity_list)

            insert_statement = (
                f"INSERT INTO Airport_Dimension "
                f"VALUES ('1', '{airport_id}', '{airport_name}', '{country}', '{city}', {latitude}, {longitude}, "
                f"'{region}', {num_runways}, {terminal_count}, {num_gates}, {atc_capacity}, {aircraft_parking_stands}, {guest_capacity});\n"
            )
            data.write(insert_statement)

# %%
generate_insert_statement(num_runways, terminal_count, num_gates, atc_capacity, parking_stands, guest_capacity)
